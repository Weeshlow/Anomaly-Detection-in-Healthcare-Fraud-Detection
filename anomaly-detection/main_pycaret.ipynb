# %%
import numpy as np
import pandas as pd

# %%
#import seaborn as sns
#import matplotlib.pyplot as plt
#import matplotlib.gridspec as gridspec

#for data preprocessing
from sklearn.decomposition import PCA

#for modeling
from sklearn.neighbors import LocalOutlierFactor
from sklearn.ensemble import IsolationForest

#filter warnings
import warnings
warnings.filterwarnings("ignore")

pd.set_option("display.max_rows",None)
pd.set_option("display.max_columns",None)

# %%
df = pd.read_csv('Healthcare_Providers.csv')
df.head()
# Out:
#      index  National Provider Identifier  \
# 0  8774979                    1891106191
# 1  3354385                    1346202256
# 2  3001884                    1306820956
# 3  7594822                    1770523540
# 4   746159                    1073627758
#
#   Last Name/Organization Name of the Provider First Name of the Provider  \
# 0                                 UPADHYAYULA                  SATYASREE
# 1                                       JONES                      WENDY
# 2                                    DUROCHER                    RICHARD
# 3                                     FULLARD                     JASPER
# 4                                    PERROTTI                    ANTHONY
#
#   Middle Initial of the Provider Credentials of the Provider  \
# 0                            NaN                        M.D.
# 1                              P                        M.D.
# 2                              W                         DPM
# 3                            NaN                          MD
# 4                              E                          DO
#
#   Gender of the Provider Entity Type of the Provider  \
# 0                      F                           I
# 1                      F                           I
# 2                      M                           I
# 3                      M                           I
# 4                      M                           I
#
#   Street Address 1 of the Provider Street Address 2 of the Provider  \
# 0                1402 S GRAND BLVD                   FDT 14TH FLOOR
# 1                  2950 VILLAGE DR                              NaN
# 2                20 WASHINGTON AVE                          STE 212
# 3               5746 N BROADWAY ST                              NaN
# 4                 875 MILITARY TRL                        SUITE 200
#
#   City of the Provider  Zip Code of the Provider State Code of the Provider  \
# 0          SAINT LOUIS               631041004.0                         MO
# 1         FAYETTEVILLE               283043815.0                         NC
# 2          NORTH HAVEN                64732343.0                         CT
# 3          KANSAS CITY               641183998.0                         MO
# 4              JUPITER               334585700.0                         FL
#
#   Country Code of the Provider            Provider Type  \
# 0                           US        Internal Medicine
# 1                           US  Obstetrics & Gynecology
# 2                           US                 Podiatry
# 3                           US        Internal Medicine
# 4                           US        Internal Medicine
#
#   Medicare Participation Indicator Place of Service HCPCS Code  \
# 0                                Y                F      99223
# 1                                Y                O      G0202
# 2                                Y                O      99348
# 3                                Y                O      81002
# 4                                Y                O      96372
#
#                                    HCPCS Description HCPCS Drug Indicator  \
# 0  Initial hospital inpatient care, typically 70 ...                    N
# 1  Screening mammography, bilateral (2-view study...                    N
# 2  Established patient home visit, typically 25 m...                    N
# 3                            Urinalysis, manual test                    N
# 4  Injection beneath the skin or into muscle for ...                    N
#
#   Number of Services Number of Medicare Beneficiaries  \
# 0                 27                               24
# 1                175                              175
# 2                 32                               13
# 3                 20                               18
# 4                 33                               24
#
#   Number of Distinct Medicare Beneficiary/Per Day Services  \
# 0                                                 27
# 1                                                175
# 2                                                 32
# 3                                                 20
# 4                                                 31
#
#   Average Medicare Allowed Amount Average Submitted Charge Amount  \
# 0                    200.58777778                    305.21111111
# 1                          123.73                           548.8
# 2                           90.65                             155
# 3                             3.5                               5
# 4                           26.52                              40
#
#   Average Medicare Payment Amount Average Medicare Standardized Amount
# 0                    157.26222222                         160.90888889
# 1                          118.83                         135.31525714
# 2                      64.4396875                           60.5959375
# 3                            3.43                                 3.43
# 4                    19.539393939                         19.057575758

# %%
df.columns
# Out:
# Index(['index', 'National Provider Identifier',
#        'Last Name/Organization Name of the Provider',
#        'First Name of the Provider', 'Middle Initial of the Provider',
#        'Credentials of the Provider', 'Gender of the Provider',
#        'Entity Type of the Provider', 'Street Address 1 of the Provider',
#        'Street Address 2 of the Provider', 'City of the Provider',
#        'Zip Code of the Provider', 'State Code of the Provider',
#        'Country Code of the Provider', 'Provider Type',
#        'Medicare Participation Indicator', 'Place of Service', 'HCPCS Code',
#        'HCPCS Description', 'HCPCS Drug Indicator', 'Number of Services',
#        'Number of Medicare Beneficiaries',
#        'Number of Distinct Medicare Beneficiary/Per Day Services',
#        'Average Medicare Allowed Amount', 'Average Submitted Charge Amount',
#        'Average Medicare Payment Amount',
#        'Average Medicare Standardized Amount'],
#       dtype='object')

# %%
DropCols = ['index', 'National Provider Identifier',
       'Last Name/Organization Name of the Provider',
       'First Name of the Provider', 'Middle Initial of the Provider','Street Address 1 of the Provider',
       'Street Address 2 of the Provider','Zip Code of the Provider',"HCPCS Code"]

# %%
df = df.drop(DropCols, axis = 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 18 columns):
#  #   Column                                                    Non-Null Count   Dtype
# ---  ------                                                    --------------   -----
#  0   Credentials of the Provider                               92791 non-null   object
#  1   Gender of the Provider                                    95746 non-null   object
#  2   Entity Type of the Provider                               100000 non-null  object
#  3   City of the Provider                                      100000 non-null  object
#  4   State Code of the Provider                                100000 non-null  object
#  5   Country Code of the Provider                              100000 non-null  object
#  6   Provider Type                                             100000 non-null  object
#  7   Medicare Participation Indicator                          100000 non-null  object
#  8   Place of Service                                          100000 non-null  object
#  9   HCPCS Description                                         100000 non-null  object
#  10  HCPCS Drug Indicator                                      100000 non-null  object
#  11  Number of Services                                        100000 non-null  object
#  12  Number of Medicare Beneficiaries                          100000 non-null  object
#  13  Number of Distinct Medicare Beneficiary/Per Day Services  100000 non-null  object
#  14  Average Medicare Allowed Amount                           100000 non-null  object
#  15  Average Submitted Charge Amount                           100000 non-null  object
#  16  Average Medicare Payment Amount                           100000 non-null  object
#  17  Average Medicare Standardized Amount                      100000 non-null  object
# dtypes: object(18)
# memory usage: 13.7+ MB

# %%
df.isnull().sum()
# Out:
# Credentials of the Provider                                 7209
# Gender of the Provider                                      4254
# Entity Type of the Provider                                    0
# City of the Provider                                           0
# State Code of the Provider                                     0
# Country Code of the Provider                                   0
# Provider Type                                                  0
# Medicare Participation Indicator                               0
# Place of Service                                               0
# HCPCS Description                                              0
# HCPCS Drug Indicator                                           0
# Number of Services                                             0
# Number of Medicare Beneficiaries                               0
# Number of Distinct Medicare Beneficiary/Per Day Services       0
# Average Medicare Allowed Amount                                0
# Average Submitted Charge Amount                                0
# Average Medicare Payment Amount                                0
# Average Medicare Standardized Amount                           0
# dtype: int64

# %%
#Since this is just a simple implementation, we will just drop the rows with missing values
df.dropna(inplace=True)
df.shape
# Out:
# (92791, 18)

# %%
# also as we can see in the case of amounts in the dataset, they are not in numeric format, so we will go ahead and
#convert them back to numeric form

def RemoveComma(x):
    return x.replace(",","")

df["Average Medicare Allowed Amount"] = pd.to_numeric(df["Average Medicare Allowed Amount"].apply(lambda x: RemoveComma(x)),
                                                             errors= "ignore")
df["Average Submitted Charge Amount"] = pd.to_numeric(df["Average Submitted Charge Amount"].apply(lambda x: RemoveComma(x)),
                                                       errors = "ignore")
df["Average Medicare Payment Amount"] = pd.to_numeric(df["Average Medicare Payment Amount"].apply(lambda x: RemoveComma(x)),
                                                       errors = "ignore")
df["Average Medicare Standardized Amount"] = pd.to_numeric(df["Average Medicare Standardized Amount"].apply(lambda x: RemoveComma(x)),
                                                             errors = "ignore")

# %%
df.dtypes
# Out:
# Credentials of the Provider                                  object
# Gender of the Provider                                       object
# Entity Type of the Provider                                  object
# City of the Provider                                         object
# State Code of the Provider                                   object
# Country Code of the Provider                                 object
# Provider Type                                                object
# Medicare Participation Indicator                             object
# Place of Service                                             object
# HCPCS Description                                            object
# HCPCS Drug Indicator                                         object
# Number of Services                                           object
# Number of Medicare Beneficiaries                             object
# Number of Distinct Medicare Beneficiary/Per Day Services     object
# Average Medicare Allowed Amount                             float64
# Average Submitted Charge Amount                             float64
# Average Medicare Payment Amount                             float64
# Average Medicare Standardized Amount                        float64
# dtype: object

# %%
import category_encoders as ce
from sklearn.preprocessing import StandardScaler

def RemoveComma(x):
    return x.replace(",","")

def Preprocessing(data):

   # Binary Encoding.

    
    BEcols = [var for var in data.columns if data[var].dtype == "O"]
    
    for col in BEcols:
        encoder = ce.BinaryEncoder(cols = [col])
        dfbin = encoder.fit_transform(data[col])
        data = pd.concat([data,dfbin], axis = 1)
        del data[col]

    #3. One-Hot-Encoding

#     data = pd.get_dummies(data,drop_first = True)
    
 
    #4. Standardization
 
    data_columns = data.columns
    std = StandardScaler()
    data = std.fit_transform(data)
    data = pd.DataFrame(data, columns = data_columns)
    
    return data


df = Preprocessing(df)

# %%
df.head()
# Out:
#    Average Medicare Allowed Amount  Average Submitted Charge Amount  \
# 0                         0.473422                        -0.032874
# 1                         0.119504                         0.237374
# 2                        -0.032825                        -0.199525
# 3                        -0.434137                        -0.365941
# 4                        -0.328133                        -0.327111
#
#    Average Medicare Payment Amount  Average Medicare Standardized Amount  \
# 0                         0.492697                              0.516248
# 1                         0.264684                              0.362760
# 2                        -0.058005                             -0.085340
# 3                        -0.419967                             -0.428170
# 4                        -0.324392                             -0.334450
#
#    Credentials of the Provider_0  Credentials of the Provider_1  \
# 0                      -0.101651                      -0.119712
# 1                      -0.101651                      -0.119712
# 2                      -0.101651                      -0.119712
# 3                      -0.101651                      -0.119712
# 4                      -0.101651                      -0.119712
#
#    Credentials of the Provider_2  Credentials of the Provider_3  \
# 0                      -0.135006                      -0.161371
# 1                      -0.135006                      -0.161371
# 2                      -0.135006                      -0.161371
# 3                      -0.135006                      -0.161371
# 4                      -0.135006                      -0.161371
#
#    Credentials of the Provider_4  Credentials of the Provider_5  \
# 0                      -0.201311                      -0.271448
# 1                      -0.201311                      -0.271448
# 2                      -0.201311                      -0.271448
# 3                      -0.201311                      -0.271448
# 4                      -0.201311                      -0.271448
#
#    Credentials of the Provider_6  Credentials of the Provider_7  \
# 0                      -0.288132                        -0.3767
# 1                      -0.288132                        -0.3767
# 2                      -0.288132                        -0.3767
# 3                      -0.288132                        -0.3767
# 4                      -0.288132                        -0.3767
#
#    Credentials of the Provider_8  Credentials of the Provider_9  \
# 0                      -0.457324                      -1.059087
# 1                      -0.457324                      -1.059087
# 2                      -0.457324                       0.944210
# 3                      -0.457324                       0.944210
# 4                       2.186635                      -1.059087
#
#    Credentials of the Provider_10  Gender of the Provider_0  \
# 0                        0.480447                 -1.533318
# 1                        0.480447                 -1.533318
# 2                       -2.081395                  0.652180
# 3                        0.480447                  0.652180
# 4                       -2.081395                  0.652180
#
#    Gender of the Provider_1  Entity Type of the Provider_0  \
# 0                  1.533318                            0.0
# 1                  1.533318                            0.0
# 2                 -0.652180                            0.0
# 3                 -0.652180                            0.0
# 4                 -0.652180                            0.0
#
#    City of the Provider_0  City of the Provider_1  City of the Provider_2  \
# 0               -0.154818               -0.348866               -0.532319
# 1               -0.154818               -0.348866               -0.532319
# 2               -0.154818               -0.348866               -0.532319
# 3               -0.154818               -0.348866               -0.532319
# 4               -0.154818               -0.348866               -0.532319
#
#    City of the Provider_3  City of the Provider_4  City of the Provider_5  \
# 0               -0.701467               -0.786385               -0.910775
# 1               -0.701467               -0.786385               -0.910775
# 2               -0.701467               -0.786385               -0.910775
# 3               -0.701467               -0.786385               -0.910775
# 4               -0.701467               -0.786385               -0.910775
#
#    City of the Provider_6  City of the Provider_7  City of the Provider_8  \
# 0               -0.930293               -0.909964               -1.019337
# 1               -0.930293               -0.909964               -1.019337
# 2               -0.930293               -0.909964               -1.019337
# 3               -0.930293               -0.909964               -1.019337
# 4               -0.930293               -0.909964               -1.019337
#
#    City of the Provider_9  City of the Provider_10  City of the Provider_11  \
# 0               -1.065936                -1.030545                -1.023478
# 1               -1.065936                -1.030545                 0.977060
# 2               -1.065936                -1.030545                 0.977060
# 3               -1.065936                 0.970361                -1.023478
# 4               -1.065936                 0.970361                -1.023478
#
#    City of the Provider_12  State Code of the Provider_0  \
# 0                 0.982426                     -0.429758
# 1                -1.017888                     -0.429758
# 2                 0.982426                     -0.429758
# 3                -1.017888                     -0.429758
# 4                 0.982426                     -0.429758
#
#    State Code of the Provider_1  State Code of the Provider_2  \
# 0                      -0.77626                     -0.815078
# 1                      -0.77626                     -0.815078
# 2                      -0.77626                     -0.815078
# 3                      -0.77626                     -0.815078
# 4                      -0.77626                     -0.815078
#
#    State Code of the Provider_3  State Code of the Provider_4  \
# 0                     -1.238586                     -0.916871
# 1                     -1.238586                      1.090666
# 2                     -1.238586                      1.090666
# 3                     -1.238586                     -0.916871
# 4                      0.807372                     -0.916871
#
#    State Code of the Provider_5  Country Code of the Provider_0  \
# 0                      0.961626                       -0.003283
# 1                     -1.039905                       -0.003283
# 2                      0.961626                       -0.003283
# 3                      0.961626                       -0.003283
# 4                     -1.039905                       -0.003283
#
#    Number of Services_5  Number of Services_6  Number of Services_7  \
# 0             -0.674095             -0.884681             -0.872396
# 1             -0.674095             -0.884681             -0.872396
# 2             -0.674095             -0.884681             -0.872396
# 3             -0.674095             -0.884681             -0.872396
# 4             -0.674095             -0.884681             -0.872396
#
#    Number of Services_8  Number of Services_9  Number of Services_10  \
# 0             -0.934433             -0.954407              -0.886288
# 1             -0.934433             -0.954407               1.128301
# 2             -0.934433             -0.954407               1.128301
# 3             -0.934433              1.047771              -0.886288
# 4             -0.934433              1.047771              -0.886288
#
#    Number of Services_11  Number of Medicare Beneficiaries_0  \
# 0               0.953562                           -0.019425
# 1              -1.048700                           -0.019425
# 2               0.953562                           -0.019425
# 3              -1.048700                           -0.019425
# 4               0.953562                           -0.019425
#
#    Number of Medicare Beneficiaries_1  Number of Medicare Beneficiaries_2  \
# 0                           -0.142077                           -0.245657
# 1                           -0.142077                           -0.245657
# 2                           -0.142077                           -0.245657
# 3                           -0.142077                           -0.245657
# 4                           -0.142077                           -0.245657
#
#    Number of Medicare Beneficiaries_3  Number of Medicare Beneficiaries_4  \
# 0                           -0.424926                           -0.535685
# 1                           -0.424926                           -0.535685
# 2                           -0.424926                           -0.535685
# 3                           -0.424926                           -0.535685
# 4                           -0.424926                           -0.535685
#
#    Number of Medicare Beneficiaries_5  Number of Medicare Beneficiaries_6  \
# 0                           -0.785039                           -0.876675
# 1                           -0.785039                           -0.876675
# 2                           -0.785039                           -0.876675
# 3                           -0.785039                           -0.876675
# 4                           -0.785039                           -0.876675
#
#    Number of Medicare Beneficiaries_7  Number of Medicare Beneficiaries_8  \
# 0                           -0.845774                           -0.908461
# 1                           -0.845774                           -0.908461
# 2                           -0.845774                           -0.908461
# 3                           -0.845774                            1.100763
# 4                           -0.845774                           -0.908461
#
#    Number of Medicare Beneficiaries_9  Number of Medicare Beneficiaries_10  \
# 0                           -1.104073                             0.912281
# 1                            0.905737                            -1.096153
# 2                            0.905737                             0.912281
# 3                           -1.104073                            -1.096153
# 4                           -1.104073                             0.912281
#
#    Number of Distinct Medicare Beneficiary/Per Day Services_0  \
# 0                                          -0.133634
# 1                                          -0.133634
# 2                                          -0.133634
# 3                                          -0.133634
# 4                                          -0.133634
#
#    Number of Distinct Medicare Beneficiary/Per Day Services_1  \
# 0                                          -0.237005
# 1                                          -0.237005
# 2                                          -0.237005
# 3                                          -0.237005
# 4                                          -0.237005
#
#    Number of Distinct Medicare Beneficiary/Per Day Services_2  \
# 0                                          -0.342968
# 1                                          -0.342968
# 2                                          -0.342968
# 3                                          -0.342968
# 4                                          -0.342968
#
#    Number of Distinct Medicare Beneficiary/Per Day Services_3  \
# 0                                          -0.507932
# 1                                          -0.507932
# 2                                          -0.507932
# 3                                          -0.507932
# 4                                          -0.507932
#
#    Number of Distinct Medicare Beneficiary/Per Day Services_4  \
# 0                                          -0.644334
# 1                                          -0.644334
# 2                                          -0.644334
# 3                                          -0.644334
# 4                                          -0.644334
#
#    Number of Distinct Medicare Beneficiary/Per Day Services_5  \
# 0                                          -0.859837
# 1                                          -0.859837
# 2                                          -0.859837
# 3                                          -0.859837
# 4                                          -0.859837
#
#    Number of Distinct Medicare Beneficiary/Per Day Services_6  \
# 0                                          -0.955149
# 1                                          -0.955149
# 2                                          -0.955149
# 3                                          -0.955149
# 4                                          -0.955149
#
#    Number of Distinct Medicare Beneficiary/Per Day Services_7  \
# 0                                           -0.95831
# 1                                           -0.95831
# 2                                           -0.95831
# 3                                           -0.95831
# 4                                           -0.95831
#
#    Number of Distinct Medicare Beneficiary/Per Day Services_8  \
# 0                                          -1.183240
# 1                                          -1.183240
# 2                                          -1.183240
# 3                                           0.845137
# 4                                           0.845137
#
#    Number of Distinct Medicare Beneficiary/Per Day Services_9  \
# 0                                          -0.923321
# 1                                           1.083046
# 2                                           1.083046
# 3                                          -0.923321
# 4                                          -0.923321
#
#    Number of Distinct Medicare Beneficiary/Per Day Services_10
# 0                                           0.822055
# 1                                          -1.216463
# 2                                           0.822055
# 3                                          -1.216463
# 4                                           0.822055

# %%
from sklearn.model_selection import train_test_split
train,test = train_test_split(df,test_size=0.2)
print(train.shape, test.shape)
# Out:
# (74232, 99) (18559, 99)

# %%
from pycaret.anomaly import *

# %%
exp_ano = setup(df)

# %%
exp = AnomalyExperiment()
exp.setup(data=train,session_id=12)

# %% [markdown]
# ## kNN implementation

# %%
knn = create_model('knn')
knn
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                      15:08:38
# Status     . . . . . . . . . . . . . . . . . .         Fitting 0.05 Fraction
# Estimator  . . . . . . . . . . . . . . . . . .  K-Nearest Neighbors Detector
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# KNN(algorithm='auto', contamination=0.05, leaf_size=30, method='largest',
#   metric='minkowski', metric_params=None, n_jobs=-1, n_neighbors=5, p=2,
#   radius=1.0)

# %%
knn_ano = assign_model(knn)
knn_ano
# Out:
#        Average Medicare Allowed Amount  Average Submitted Charge Amount  \
# 0                             0.473422                        -0.032874
# 1                             0.119504                         0.237374
# 2                            -0.032825                        -0.199525
# 3                            -0.434137                        -0.365941
# 4                            -0.328133                        -0.327111
# ...                                ...                              ...
# 92786                        -0.428243                        -0.331549
# 92787                        -0.139795                        -0.092241
# 92788                        -0.057127                        -0.134068
# 92789                        -0.168115                        -0.211672
# 92790                        -0.367459                        -0.249954
#
#        Average Medicare Payment Amount  Average Medicare Standardized Amount  \
# 0                             0.492697                              0.516248
# 1                             0.264684                              0.362760
# 2                            -0.058005                             -0.085340
# 3                            -0.419967                             -0.428170
# 4                            -0.324392                             -0.334450
# ...                                ...                                   ...
# 92786                        -0.413068                             -0.417225
# 92787                        -0.202669                             -0.166786
# 92788                        -0.080041                             -0.075429
# 92789                        -0.262294                             -0.226606
# 92790                        -0.356722                             -0.361062
#
#        Credentials of the Provider_0  Credentials of the Provider_1  \
# 0                          -0.101651                      -0.119712
# 1                          -0.101651                      -0.119712
# 2                          -0.101651                      -0.119712
# 3                          -0.101651                      -0.119712
# 4                          -0.101651                      -0.119712
# ...                              ...                            ...
# 92786                      -0.101651                      -0.119712
# 92787                      -0.101651                      -0.119712
# 92788                      -0.101651                      -0.119712
# 92789                      -0.101651                      -0.119712
# 92790                      -0.101651                      -0.119712
#
#        Credentials of the Provider_2  Credentials of the Provider_3  \
# 0                          -0.135006                      -0.161371
# 1                          -0.135006                      -0.161371
# 2                          -0.135006                      -0.161371
# 3                          -0.135006                      -0.161371
# 4                          -0.135006                      -0.161371
# ...                              ...                            ...
# 92786                      -0.135006                      -0.161371
# 92787                      -0.135006                      -0.161371
# 92788                      -0.135006                      -0.161371
# 92789                      -0.135006                      -0.161371
# 92790                      -0.135006                      -0.161371
#
#        Credentials of the Provider_4  Credentials of the Provider_5  \
# 0                          -0.201311                      -0.271448
# 1                          -0.201311                      -0.271448
# 2                          -0.201311                      -0.271448
# 3                          -0.201311                      -0.271448
# 4                          -0.201311                      -0.271448
# ...                              ...                            ...
# 92786                      -0.201311                      -0.271448
# 92787                      -0.201311                      -0.271448
# 92788                      -0.201311                      -0.271448
# 92789                      -0.201311                      -0.271448
# 92790                      -0.201311                      -0.271448
#
#        Credentials of the Provider_6  Credentials of the Provider_7  \
# 0                          -0.288132                      -0.376700
# 1                          -0.288132                      -0.376700
# 2                          -0.288132                      -0.376700
# 3                          -0.288132                      -0.376700
# 4                          -0.288132                      -0.376700
# ...                              ...                            ...
# 92786                      -0.288132                      -0.376700
# 92787                      -0.288132                      -0.376700
# 92788                       3.470629                       2.654636
# 92789                      -0.288132                       2.654636
# 92790                      -0.288132                      -0.376700
#
#        Credentials of the Provider_8  Credentials of the Provider_9  \
# 0                          -0.457324                      -1.059087
# 1                          -0.457324                      -1.059087
# 2                          -0.457324                       0.944210
# 3                          -0.457324                       0.944210
# 4                           2.186635                      -1.059087
# ...                              ...                            ...
# 92786                      -0.457324                      -1.059087
# 92787                      -0.457324                       0.944210
# 92788                      -0.457324                       0.944210
# 92789                      -0.457324                      -1.059087
# 92790                      -0.457324                      -1.059087
#
#        Credentials of the Provider_10  Gender of the Provider_0  \
# 0                            0.480447                 -1.533318
# 1                            0.480447                 -1.533318
# 2                           -2.081394                  0.652180
# 3                            0.480447                  0.652180
# 4                           -2.081394                  0.652180
# ...                               ...                       ...
# 92786                        0.480447                  0.652180
# 92787                        0.480447                  0.652180
# 92788                        0.480447                 -1.533318
# 92789                        0.480447                 -1.533318
# 92790                        0.480447                  0.652180
#
#        Gender of the Provider_1  Entity Type of the Provider_0  \
# 0                      1.533318                            0.0
# 1                      1.533318                            0.0
# 2                     -0.652180                            0.0
# 3                     -0.652180                            0.0
# 4                     -0.652180                            0.0
# ...                         ...                            ...
# 92786                 -0.652180                            0.0
# 92787                 -0.652180                            0.0
# 92788                  1.533318                            0.0
# 92789                  1.533318                            0.0
# 92790                 -0.652180                            0.0
#
#        City of the Provider_0  City of the Provider_1  City of the Provider_2  \
# 0                   -0.154818               -0.348866               -0.532319
# 1                   -0.154818               -0.348866               -0.532319
# 2                   -0.154818               -0.348866               -0.532319
# 3                   -0.154818               -0.348866               -0.532319
# 4                   -0.154818               -0.348866               -0.532319
# ...                       ...                     ...                     ...
# 92786               -0.154818               -0.348866               -0.532319
# 92787               -0.154818                2.866431                1.878574
# 92788               -0.154818               -0.348866               -0.532319
# 92789               -0.154818               -0.348866                1.878574
# 92790               -0.154818               -0.348866               -0.532319
#
#        City of the Provider_3  City of the Provider_4  City of the Provider_5  \
# 0                   -0.701467               -0.786385               -0.910775
# 1                   -0.701467               -0.786385               -0.910775
# 2                   -0.701467               -0.786385               -0.910775
# 3                   -0.701467               -0.786385               -0.910775
# 4                   -0.701467               -0.786385               -0.910775
# ...                       ...                     ...                     ...
# 92786                1.425583               -0.786385                1.097966
# 92787                1.425583               -0.786385               -0.910775
# 92788               -0.701467                1.271643                1.097966
# 92789               -0.701467               -0.786385               -0.910775
# 92790               -0.701467               -0.786385               -0.910775
#
#        City of the Provider_6  City of the Provider_7  City of the Provider_8  \
# 0                   -0.930293               -0.909964               -1.019338
# 1                   -0.930293               -0.909964               -1.019338
# 2                   -0.930293               -0.909964               -1.019338
# 3                   -0.930293               -0.909964               -1.019338
# 4                   -0.930293               -0.909964               -1.019338
# ...                       ...                     ...                     ...
# 92786                1.074930               -0.909964               -1.019338
# 92787               -0.930293                1.098945               -1.019338
# 92788               -0.930293               -0.909964               -1.019338
# 92789                1.074930                1.098945                0.981029
# 92790               -0.930293               -0.909964               -1.019338
#
#        City of the Provider_9  City of the Provider_10  \
# 0                   -1.065936                -1.030545
# 1                   -1.065936                -1.030545
# 2                   -1.065936                -1.030545
# 3                   -1.065936                 0.970361
# 4                   -1.065936                 0.970361
# ...                       ...                      ...
# 92786                0.938142                -1.030545
# 92787                0.938142                -1.030545
# 92788                0.938142                 0.970361
# 92789               -1.065936                -1.030545
# 92790               -1.065936                -1.030545
#
#        City of the Provider_11  City of the Provider_12  \
# 0                    -1.023478                 0.982426
# 1                     0.977060                -1.017888
# 2                     0.977060                 0.982426
# 3                    -1.023478                -1.017888
# 4                    -1.023478                 0.982426
# ...                        ...                      ...
# 92786                 0.977060                 0.982426
# 92787                 0.977060                -1.017888
# 92788                -1.023478                 0.982426
# 92789                -1.023478                -1.017888
# 92790                -1.023478                 0.982426
#
#        State Code of the Provider_0  State Code of the Provider_1  \
# 0                         -0.429758                     -0.776260
# 1                         -0.429758                     -0.776260
# 2                         -0.429758                     -0.776260
# 3                         -0.429758                     -0.776260
# 4                         -0.429758                     -0.776260
# ...                             ...                           ...
# 92786                     -0.429758                      1.288227
# 92787                     -0.429758                      1.288227
# 92788                     -0.429758                      1.288227
# 92789                     -0.429758                      1.288227
# 92790                     -0.429758                     -0.776260
#
#        State Code of the Provider_2  State Code of the Provider_3  \
# 0                         -0.815078                     -1.238586
# 1                         -0.815078                     -1.238586
# 2                         -0.815078                     -1.238586
# 3                         -0.815078                     -1.238586
# 4                         -0.815078                      0.807372
# ...                             ...                           ...
# 92786                      1.226876                     -1.238586
# 92787                     -0.815078                     -1.238586
# 92788                      1.226876                     -1.238586
# 92789                      1.226876                      0.807372
# 92790                     -0.815078                     -1.238586
#
#        State Code of the Provider_4  State Code of the Provider_5  \
# 0                         -0.916871                      0.961626
# 1                          1.090666                     -1.039905
# 2                          1.090666                      0.961626
# 3                         -0.916871                      0.961626
# 3                 -0.371872             -0.521434             -0.674095
# 4                 -0.371872             -0.521434             -0.674095
# ...                     ...                   ...                   ...
# 92786             -0.371872             -0.521434              1.483470
# 92787             -0.371872              1.917787             -0.674095
# 92788             -0.371872             -0.521434             -0.674095
# 92789             -0.371872              1.917787              1.483470
# 92790             -0.371872             -0.521434             -0.674095
#
#        Number of Services_6  Number of Services_7  Number of Services_8  \
# 0                 -0.884681             -0.872396             -0.934433
# 1                 -0.884681             -0.872396             -0.934433
# 2                 -0.884681             -0.872396             -0.934433
# 3                 -0.884681             -0.872396             -0.934433
# 4                 -0.884681             -0.872396             -0.934433
# ...                     ...                   ...                   ...
# 92786             -0.884681              1.146269             -0.934433
# 92787             -0.884681              1.146269             -0.934433
# 92788             -0.884681             -0.872396             -0.934433
# 92789             -0.884681             -0.872396              1.070167
# 92790              1.130352             -0.872396             -0.934433
#
#        Number of Services_9  Number of Services_10  Number of Services_11  \
# 0                 -0.954407              -0.886288               0.953562
# 1                 -0.954407               1.128301              -1.048700
# 2                 -0.954407               1.128301               0.953562
# 3                  1.047771              -0.886288              -1.048700
# 4                  1.047771              -0.886288               0.953562
# ...                     ...                    ...                    ...
# 92786              1.047771               1.128301              -1.048700
# 92787             -0.954407               1.128301              -1.048700
# 92788              1.047771              -0.886288              -1.048700
# 92789             -0.954407               1.128301              -1.048700
# 92790              1.047771              -0.886288               0.953562
#
#        Number of Medicare Beneficiaries_0  Number of Medicare Beneficiaries_1  \
# 0                               -0.019425                           -0.142077
# 1                               -0.019425                           -0.142077
# 2                               -0.019425                           -0.142077
# 3                               -0.019425                           -0.142077
# 4                               -0.019425                           -0.142077
# ...                                   ...                                 ...
# 92786                           -0.019425                           -0.142077
# 92787                           -0.019425                           -0.142077
# 92788                           -0.019425                           -0.142077
# 92789                           -0.019425                           -0.142077
# 92790                           -0.019425                           -0.142077
#
#        Number of Medicare Beneficiaries_2  Number of Medicare Beneficiaries_3  \
# 0                               -0.245657                           -0.424926
# 1                               -0.245657                           -0.424926
# 2                               -0.245657                           -0.424926
# 3                               -0.245657                           -0.424926
# 4                               -0.245657                           -0.424926
# ...                                   ...                                 ...
# 92786                           -0.245657                           -0.424926
# 92787                           -0.245657                            2.353351
# 92788                           -0.245657                           -0.424926
# 92789                           -0.245657                            2.353351
# 92790                           -0.245657                           -0.424926
#
#        Number of Medicare Beneficiaries_4  Number of Medicare Beneficiaries_5  \
# 0                               -0.535685                           -0.785039
# 1                               -0.535685                           -0.785039
# 2                               -0.535685                           -0.785039
# 3                               -0.535685                           -0.785039
# 4                               -0.535685                           -0.785039
# ...                                   ...                                 ...
# 92786                            1.866768                            1.273822
# 92787                            1.866768                           -0.785039
# 92788                           -0.535685                           -0.785039
# 92789                           -0.535685                           -0.785039
# 92790                           -0.535685                            1.273822
#
#        Number of Medicare Beneficiaries_6  Number of Medicare Beneficiaries_7  \
# 0                               -0.876675                           -0.845774
# 1                               -0.876675                           -0.845774
# 2                               -0.876675                           -0.845774
# 3                               -0.876675                           -0.845774
# 4                               -0.876675                           -0.845774
# ...                                   ...                                 ...
# 92786                            1.140673                           -0.845774
# 92787                           -0.876675                           -0.845774
# 92788                           -0.876675                            1.182349
# 92789                           -0.876675                           -0.845774
# 92790                           -0.876675                           -0.845774
#
#        Number of Medicare Beneficiaries_8  Number of Medicare Beneficiaries_9  \
# 0                               -0.908461                           -1.104073
# 1                               -0.908461                            0.905737
# 2                               -0.908461                            0.905737
# 3                                1.100763                           -1.104073
# 4                               -0.908461                           -1.104073
# ...                                   ...                                 ...
# 92786                           -0.908461                            0.905737
# 92787                           -0.908461                           -1.104073
# 92788                           -0.908461                            0.905737
# 92789                            1.100763                           -1.104073
# 92790                           -0.908461                            0.905737
#
#        Number of Medicare Beneficiaries_10  \
# 0                                 0.912281
# 1                                -1.096153
# 2                                 0.912281
# 3                                -1.096153
# 4                                 0.912281
# ...                                    ...
# 92786                            -1.096153
# 92787                             0.912281
# 92788                            -1.096153
# 92789                            -1.096153
# 92790                            -1.096153
#
#        Number of Distinct Medicare Beneficiary/Per Day Services_0  \
# 0                                              -0.133634
# 1                                              -0.133634
# 2                                              -0.133634
# 3                                              -0.133634
# 4                                              -0.133634
# ...                                                  ...
# 92786                                          -0.133634
# 92787                                          -0.133634
# 92788                                          -0.133634
# 92789                                          -0.133634
# 92790                                          -0.133634
#
#        Number of Distinct Medicare Beneficiary/Per Day Services_1  \
# 0                                              -0.237005
# 1                                              -0.237005
# 2                                              -0.237005
# 3                                              -0.237005
# 4                                              -0.237005
# ...                                                  ...
# 92786                                          -0.237005
# 92787                                          -0.237005
# 92788                                          -0.237005
# 92789                                          -0.237005
# 92790                                          -0.237005
#
#        Number of Distinct Medicare Beneficiary/Per Day Services_2  \
# 0                                              -0.342968
# 1                                              -0.342968
# 2                                              -0.342968
# 3                                              -0.342968
# 4                                              -0.342968
# ...                                                  ...
# 92786                                          -0.342968
# 92787                                          -0.342968
# 92788                                          -0.342968
# 92789                                          -0.342968
# 92790                                          -0.342968
#
#        Number of Distinct Medicare Beneficiary/Per Day Services_3  \
# 0                                              -0.507932
# 1                                              -0.507932
# 2                                              -0.507932
# 3                                              -0.507932
# 4                                              -0.507932
# ...                                                  ...
# 92786                                          -0.507932
# 92787                                           1.968766
# 92788                                          -0.507932
# 92789                                           1.968766
# 92790                                          -0.507932
#
#        Number of Distinct Medicare Beneficiary/Per Day Services_4  \
# 0                                              -0.644334
# 1                                              -0.644334
# 2                                              -0.644334
# 3                                              -0.644334
# 4                                              -0.644334
# ...                                                  ...
# 92786                                           1.551991
# 92787                                          -0.644334
# 92788                                          -0.644334
# 92789                                          -0.644334
# 92790                                          -0.644334
#
#        Number of Distinct Medicare Beneficiary/Per Day Services_5  \
# 0                                              -0.859837
# 1                                              -0.859837
# 2                                              -0.859837
# 3                                              -0.859837
# 4                                              -0.859837
# ...                                                  ...
# 92786                                          -0.859837
# 92787                                          -0.859837
# 92788                                          -0.859837
# 92789                                           1.163011
# 92790                                           1.163011
#
#        Number of Distinct Medicare Beneficiary/Per Day Services_6  \
# 0                                              -0.955149
# 1                                              -0.955149
# 2                                              -0.955149
# 3                                              -0.955149
# 4                                              -0.955149
# ...                                                  ...
# 92786                                           1.046957
# 92787                                          -0.955149
# 92788                                          -0.955149
# 92789                                          -0.955149
# 92790                                          -0.955149
#
#        Number of Distinct Medicare Beneficiary/Per Day Services_7  \
# 0                                              -0.958310
# 1                                              -0.958310
# 2                                              -0.958310
# 3                                              -0.958310
# 4                                              -0.958310
# ...                                                  ...
# 92786                                          -0.958310
# 92787                                           1.043503
# 92788                                          -0.958310
# 92789                                           1.043503
# 92790                                          -0.958310
#
#        Number of Distinct Medicare Beneficiary/Per Day Services_8  \
# 0                                              -1.183240
# 1                                              -1.183240
# 2                                              -1.183240
# 3                                               0.845137
# 4                                               0.845137
# ...                                                  ...
# 92786                                          -1.183240
# 92787                                          -1.183240
# 92788                                           0.845137
# 92789                                          -1.183240
# 92790                                           0.845137
#
#        Number of Distinct Medicare Beneficiary/Per Day Services_9  \
# 0                                              -0.923321
# 1                                               1.083046
# 2                                               1.083046
# 3                                              -0.923321
# 4                                              -0.923321
# ...                                                  ...
# 92786                                          -0.923321
# 92787                                           1.083046
# 92788                                          -0.923321
# 92789                                          -0.923321
# 92790                                          -0.923321
#
#        Number of Distinct Medicare Beneficiary/Per Day Services_10  Anomaly  \
# 0                                               0.822055                  0
# 1                                              -1.216463                  0
# 2                                               0.822055                  0
# 3                                              -1.216463                  0
# 4                                               0.822055                  0
# ...                                                  ...                ...
# 92786                                          -1.216463                  0
# 92787                                          -1.216463                  0
# 92788                                          -1.216463                  0
# 92789                                           0.822055                  0
# 92790                                           0.822055                  0
#
#        Anomaly_Score
# 0           6.676844
# 1           6.766214
# 2           6.695740
# 3           6.307742
# 4           7.076800
# ...              ...
# 92786       7.660293
# 92787      10.357867
# 92788       7.393060
# 92789       8.594176
# 92790       5.837622
#
# [92791 rows x 101 columns]

# %%
knn_ano['Anomaly'].value_counts()
# Out:
# 0    88151
# 1     4640
# Name: Anomaly, dtype: int64

# %%
#plot_model(knn, plot = 'tsne')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\medical-fraud\main\anamoly-detection\main_pycaret.ipynb Cell 22 in 1
# ----> <a href='vscode-notebook-cell:/d%3A/medical-fraud/main/anamoly-detection/main_pycaret.ipynb#X35sZmlsZQ%3D%3D?line=0'>1</a> plot_model(knn, plot = 'tsne')
#
# File c:\Users\mayank.monu\AppData\Local\Programs\Python\Python38\lib\site-packages\pycaret\utils\generic.py:965, in check_if_global_is_not_none.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     963     if globals_d[name] is None:
#     964         raise ValueError(message)
# --> 965 return func(*args, **kwargs)
#
# File c:\Users\mayank.monu\AppData\Local\Programs\Python\Python38\lib\site-packages\pycaret\anomaly\functional.py:699, in plot_model(model, plot, feature, label, scale, save, display_format)
#     636 @check_if_global_is_not_none(globals(), _CURRENT_EXPERIMENT_DECORATOR_DICT)
#     637 def plot_model(
#     638     model,
#    (...)
#     644     display_format: Optional[str] = None,
#     645 ) -> Optional[str]:
#     647     """
#     648     This function analyzes the performance of a trained model.
#     649
#    (...)
#     697
#     698     """
# --> 699     return _CURRENT_EXPERIMENT.plot_model(
#     700         model,
#     701         plot=plot,
#     702         feature_name=feature,
#     703         label=label,
#     704         scale=scale,
#     705         save=save,
#     706         display_format=display_format,
#     707     )
#
# File c:\Users\mayank.monu\AppData\Local\Programs\Python\Python38\lib\site-packages\pycaret\anomaly\oop.py:157, in AnomalyExperiment.plot_model(self, estimator, plot, scale, save, fold, fit_kwargs, plot_kwargs, groups, feature_name, label, use_train_data, verbose, display_format)
#      89 def plot_model(
#      90     self,
#      91     estimator,
#    (...)
#     103     display_format: Optional[str] = None,
#     104 ) -> Optional[str]:
#     105     """
#     106     This function analyzes the performance of a trained model.
#     107
#    (...)
#     155
#     156     """
# --> 157     return super().plot_model(
#     158         estimator,
#     159         plot,
#     160         scale,
#     161         save,
#     162         fold,
#     163         fit_kwargs,
#     164         plot_kwargs,
#     165         groups,
#     166         feature_name,
#     167         label,
#     168         use_train_data,
#     169         verbose,
#     170         display_format,
#     171     )
#
# File c:\Users\mayank.monu\AppData\Local\Programs\Python\Python38\lib\site-packages\pycaret\internal\pycaret_experiment\tabular_experiment.py:2078, in _TabularExperiment.plot_model(self, estimator, plot, scale, save, fold, fit_kwargs, plot_kwargs, groups, feature_name, label, use_train_data, verbose, display_format)
#    1964 def plot_model(
#    1965     self,
#    1966     estimator,
#    (...)
#    1978     display_format: Optional[str] = None,
#    1979 ) -> Optional[str]:
#    1981     """
#    1982     This function takes a trained model object and returns a plot based on the
#    1983     test / hold-out set. The process may require the model to be re-trained in
#    (...)
#    2076
#    2077     """
# -> 2078     return self._plot_model(
#    2079         estimator=estimator,
#    2080         plot=plot,
#    2081         scale=scale,
#    2082         save=save,
#    2083         fold=fold,
#    2084         fit_kwargs=fit_kwargs,
#    2085         plot_kwargs=plot_kwargs,
#    2086         groups=groups,
#    2087         feature_name=feature_name,
#    2088         label=label,
#    2089         use_train_data=use_train_data,
#    2090         verbose=verbose,
#    2091         display_format=display_format,
#    2092     )
#
# File c:\Users\mayank.monu\AppData\Local\Programs\Python\Python38\lib\site-packages\pycaret\internal\pycaret_experiment\tabular_experiment.py:1944, in _TabularExperiment._plot_model(self, estimator, plot, scale, save, fold, fit_kwargs, plot_kwargs, groups, feature_name, label, use_train_data, verbose, system, display, display_format)
#    1942 # execute the plot method
#    1943 with redirect_output(self.logger):
# -> 1944     ret = locals()[plot]()
#    1945 if ret:
#    1946     plot_filename = ret
#
# File c:\Users\mayank.monu\AppData\Local\Programs\Python\Python38\lib\site-packages\pycaret\internal\pycaret_experiment\tabular_experiment.py:793, in _TabularExperiment._plot_model.<locals>.tsne()
#     791     return _tsne_clustering()
#     792 else:
# --> 793     return _tsne_anomaly()
#
# File c:\Users\mayank.monu\AppData\Local\Programs\Python\Python38\lib\site-packages\pycaret\internal\pycaret_experiment\tabular_experiment.py:814, in _TabularExperiment._plot_model.<locals>._tsne_anomaly()
#     811 from sklearn.manifold import TSNE
#     813 self.logger.info("Fitting TSNE()")
# --> 814 X_embedded = TSNE(n_components=3).fit_transform(b)
#     816 X = pd.DataFrame(X_embedded)
#     817 X["Anomaly"] = cluster
#
# File c:\Users\mayank.monu\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\manifold\_t_sne.py:1123, in TSNE.fit_transform(self, X, y)
#    1103 """Fit X into an embedded space and return that transformed output.
#    1104
#    1105 Parameters
#    (...)
#    1120     Embedding of the training data in low-dimensional space.
#    1121 """
#    1122 self._check_params_vs_input(X)
# -> 1123 embedding = self._fit(X)
#    1124 self.embedding_ = embedding
#    1125 return self.embedding_
#
# File c:\Users\mayank.monu\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\manifold\_t_sne.py:962, in TSNE._fit(self, X, skip_num_points)
#     955     print(
#     956         "[t-SNE] Indexed {} samples in {:.3f}s...".format(
#     957             n_samples, duration
#     958         )
#     959     )
#     961 t0 = time()
# --> 962 distances_nn = knn.kneighbors_graph(mode="distance")
#     963 duration = time() - t0
#     964 if self.verbose:
#
# File c:\Users\mayank.monu\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\neighbors\_base.py:924, in KNeighborsMixin.kneighbors_graph(self, X, n_neighbors, mode)
#     921     A_data = np.ones(n_queries * n_neighbors)
#     923 elif mode == "distance":
# --> 924     A_data, A_ind = self.kneighbors(X, n_neighbors, return_distance=True)
#     925     A_data = np.ravel(A_data)
#     927 else:
#
# File c:\Users\mayank.monu\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\neighbors\_base.py:796, in KNeighborsMixin.kneighbors(self, X, n_neighbors, return_distance)
#     793     else:
#     794         kwds = self.effective_metric_params_
# --> 796     chunked_results = list(
#     797         pairwise_distances_chunked(
#     798             X,
#     799             self._fit_X,
#     800             reduce_func=reduce_func,
#     801             metric=self.effective_metric_,
#     802             n_jobs=n_jobs,
#     803             **kwds,
#     804         )
#     805     )
#     807 elif self._fit_method in ["ball_tree", "kd_tree"]:
#     808     if issparse(X):
#
# File c:\Users\mayank.monu\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\metrics\pairwise.py:1860, in pairwise_distances_chunked(X, Y, reduce_func, metric, n_jobs, working_memory, **kwds)
#    1858     chunk_size = D_chunk.shape[0]
#    1859     D_chunk = reduce_func(D_chunk, sl.start)
# -> 1860     _check_chunk_size(D_chunk, chunk_size)
#    1861 yield D_chunk
#
# File c:\Users\mayank.monu\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\metrics\pairwise.py:1645, in _check_chunk_size(reduced, chunk_size)
#    1612 _VALID_METRICS = [
#    1613     "euclidean",
#    1614     "l2",
#    (...)
#    1639     "haversine",
#    1640 ]
#    1642 _NAN_METRICS = ["nan_euclidean"]
# -> 1645 def _check_chunk_size(reduced, chunk_size):
#    1646     """Checks chunk is a sequence of expected size or a tuple of same."""
#    1647     if reduced is None:
#
# KeyboardInterrupt:

# %% [markdown]
# ## iForest Implementation

# %%
iforest = create_model('iforest')
iforest
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .               15:19:02
# Status     . . . . . . . . . . . . . . . . . .  Fitting 0.05 Fraction
# Estimator  . . . . . . . . . . . . . . . . . .       Isolation Forest
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# IForest(behaviour='new', bootstrap=False, contamination=0.05,
#     max_features=1.0, max_samples='auto', n_estimators=100, n_jobs=-1,
#     random_state=5852, verbose=0)

# %%
i_ano = assign_model(iforest)
i_ano
# Out:
#        Average Medicare Allowed Amount  Average Submitted Charge Amount  \
# 0                             0.473422                        -0.032874
# 1                             0.119504                         0.237374
# 2                            -0.032825                        -0.199525
# 3                            -0.434137                        -0.365941
# 4                            -0.328133                        -0.327111
# ...                                ...                              ...
# 92786                        -0.428243                        -0.331549
# 92787                        -0.139795                        -0.092241
# 92788                        -0.057127                        -0.134068
# 92789                        -0.168115                        -0.211672
# 92790                        -0.367459                        -0.249954
#
#        Average Medicare Payment Amount  Average Medicare Standardized Amount  \
# 0                             0.492697                              0.516248
# 1                             0.264684                              0.362760
# 2                            -0.058005                             -0.085340
# 3                            -0.419967                             -0.428170
# 4                            -0.324392                             -0.334450
# ...                                ...                                   ...
# 92786                        -0.413068                             -0.417225
# 92787                        -0.202669                             -0.166786
# 92788                        -0.080041                             -0.075429
# 92789                        -0.262294                             -0.226606
# 92790                        -0.356722                             -0.361062
#
#        Credentials of the Provider_0  Credentials of the Provider_1  \
# 0                          -0.101651                      -0.119712
# 1                          -0.101651                      -0.119712
# 2                          -0.101651                      -0.119712
# 3                          -0.101651                      -0.119712
# 4                          -0.101651                      -0.119712
# ...                              ...                            ...
# 92786                      -0.101651                      -0.119712
# 92787                      -0.101651                      -0.119712
# 92788                      -0.101651                      -0.119712
# 92789                      -0.101651                      -0.119712
# 92790                      -0.101651                      -0.119712
#
#        Credentials of the Provider_2  Credentials of the Provider_3  \
# 0                          -0.135006                      -0.161371
# 1                          -0.135006                      -0.161371
# 2                          -0.135006                      -0.161371
# 3                          -0.135006                      -0.161371
# 4                          -0.135006                      -0.161371
# ...                              ...                            ...
# 92786                      -0.135006                      -0.161371
# 92787                      -0.135006                      -0.161371
# 92788                      -0.135006                      -0.161371
# 92789                      -0.135006                      -0.161371
# 92790                      -0.135006                      -0.161371
#
#        Credentials of the Provider_4  Credentials of the Provider_5  \
# 0                          -0.201311                      -0.271448
# 1                          -0.201311                      -0.271448
# 2                          -0.201311                      -0.271448
# 3                          -0.201311                      -0.271448
# 4                          -0.201311                      -0.271448
# ...                              ...                            ...
# 92786                      -0.201311                      -0.271448
# 92787                      -0.201311                      -0.271448
# 92788                      -0.201311                      -0.271448
# 92789                      -0.201311                      -0.271448
# 92790                      -0.201311                      -0.271448
#
#        Credentials of the Provider_6  Credentials of the Provider_7  \
# 0                          -0.288132                      -0.376700
# 1                          -0.288132                      -0.376700
# 2                          -0.288132                      -0.376700
# 3                          -0.288132                      -0.376700
# 4                          -0.288132                      -0.376700
# ...                              ...                            ...
# 92786                      -0.288132                      -0.376700
# 92787                      -0.288132                      -0.376700
# 92788                       3.470629                       2.654636
# 92789                      -0.288132                       2.654636
# 92790                      -0.288132                      -0.376700
#
#        Credentials of the Provider_8  Credentials of the Provider_9  \
# 0                          -0.457324                      -1.059087
# 1                          -0.457324                      -1.059087
# 2                          -0.457324                       0.944210
# 3                          -0.457324                       0.944210
# 4                           2.186635                      -1.059087
# ...                              ...                            ...
# 92786                      -0.457324                      -1.059087
# 92787                      -0.457324                       0.944210
# 92788                      -0.457324                       0.944210
# 92789                      -0.457324                      -1.059087
# 92790                      -0.457324                      -1.059087
#
#        Credentials of the Provider_10  Gender of the Provider_0  \
# 0                            0.480447                 -1.533318
# 1                            0.480447                 -1.533318
# 2                           -2.081394                  0.652180
# 3                            0.480447                  0.652180
# 4                           -2.081394                  0.652180
# ...                               ...                       ...
# 92786                        0.480447                  0.652180
# 92787                        0.480447                  0.652180
# 92788                        0.480447                 -1.533318
# 92789                        0.480447                 -1.533318
# 92790                        0.480447                  0.652180
#
#        Gender of the Provider_1  Entity Type of the Provider_0  \
# 0                      1.533318                            0.0
# 1                      1.533318                            0.0
# 2                     -0.652180                            0.0
# 3                     -0.652180                            0.0
# 4                     -0.652180                            0.0
# ...                         ...                            ...
# 92786                 -0.652180                            0.0
# 92787                 -0.652180                            0.0
# 92788                  1.533318                            0.0
# 92789                  1.533318                            0.0
# 92790                 -0.652180                            0.0
#
#        City of the Provider_0  City of the Provider_1  City of the Provider_2  \
# 0                   -0.154818               -0.348866               -0.532319
# 1                   -0.154818               -0.348866               -0.532319
# 2                   -0.154818               -0.348866               -0.532319
# 3                   -0.154818               -0.348866               -0.532319
# 4                   -0.154818               -0.348866               -0.532319
# ...                       ...                     ...                     ...
# 92786               -0.154818               -0.348866               -0.532319
# 92787               -0.154818                2.866431                1.878574
# 92788               -0.154818               -0.348866               -0.532319
# 92789               -0.154818               -0.348866                1.878574
# 92790               -0.154818               -0.348866               -0.532319
#
#        City of the Provider_3  City of the Provider_4  City of the Provider_5  \
# 0                   -0.701467               -0.786385               -0.910775
# 1                   -0.701467               -0.786385               -0.910775
# 2                   -0.701467               -0.786385               -0.910775
# 3                   -0.701467               -0.786385               -0.910775
# 4                   -0.701467               -0.786385               -0.910775
# ...                       ...                     ...                     ...
# 92786                1.425583               -0.786385                1.097966
# 92787                1.425583               -0.786385               -0.910775
# 92788               -0.701467                1.271643                1.097966
# 92789               -0.701467               -0.786385               -0.910775
# 92790               -0.701467               -0.786385               -0.910775
#
#        City of the Provider_6  City of the Provider_7  City of the Provider_8  \
# 0                   -0.930293               -0.909964               -1.019338
# 1                   -0.930293               -0.909964               -1.019338
# 2                   -0.930293               -0.909964               -1.019338
# 3                   -0.930293               -0.909964               -1.019338
# 4                   -0.930293               -0.909964               -1.019338
# ...                       ...                     ...                     ...
# 92786                1.074930               -0.909964               -1.019338
# 92787               -0.930293                1.098945               -1.019338
# 92788               -0.930293               -0.909964               -1.019338
# 92789                1.074930                1.098945                0.981029
# 92790               -0.930293               -0.909964               -1.019338
#
#        City of the Provider_9  City of the Provider_10  \
# 0                   -1.065936                -1.030545
# 1                   -1.065936                -1.030545
# 2                   -1.065936                -1.030545
# 3                   -1.065936                 0.970361
# 4                   -1.065936                 0.970361
# ...                       ...                      ...
# 92786                0.938142                -1.030545
# 92787                0.938142                -1.030545
# 92788                0.938142                 0.970361
# 92789               -1.065936                -1.030545
# 92790               -1.065936                -1.030545
#
#        City of the Provider_11  City of the Provider_12  \
# 0                    -1.023478                 0.982426
# 1                     0.977060                -1.017888
# 2                     0.977060                 0.982426
# 3                    -1.023478                -1.017888
# 4                    -1.023478                 0.982426
# ...                        ...                      ...
# 92786                 0.977060                 0.982426
# 92787                 0.977060                -1.017888
# 92788                -1.023478                 0.982426
# 92789                -1.023478                -1.017888
# 92790                -1.023478                 0.982426
#
#        State Code of the Provider_0  State Code of the Provider_1  \
# 0                         -0.429758                     -0.776260
# 1                         -0.429758                     -0.776260
# 2                         -0.429758                     -0.776260
# 3                         -0.429758                     -0.776260
# 4                         -0.429758                     -0.776260
# ...                             ...                           ...
# 92786                     -0.429758                      1.288227
# 92787                     -0.429758                      1.288227
# 92788                     -0.429758                      1.288227
# 0                 -0.072486             -0.167217             -0.272659
# 1                 -0.072486             -0.167217             -0.272659
# 2                 -0.072486             -0.167217             -0.272659
# 3                 -0.072486             -0.167217             -0.272659
# 4                 -0.072486             -0.167217             -0.272659
# ...                     ...                   ...                   ...
# 92786             -0.072486             -0.167217             -0.272659
# 92787             -0.072486             -0.167217             -0.272659
# 92788             -0.072486             -0.167217             -0.272659
# 92789             -0.072486             -0.167217             -0.272659
# 92790             -0.072486             -0.167217             -0.272659
#
#        Number of Services_3  Number of Services_4  Number of Services_5  \
# 0                 -0.371872             -0.521434             -0.674095
# 1                 -0.371872             -0.521434             -0.674095
# 2                 -0.371872             -0.521434             -0.674095
# 3                 -0.371872             -0.521434             -0.674095
# 4                 -0.371872             -0.521434             -0.674095
# ...                     ...                   ...                   ...
# 92786             -0.371872             -0.521434              1.483470
# 92787             -0.371872              1.917787             -0.674095
# 92788             -0.371872             -0.521434             -0.674095
# 92789             -0.371872              1.917787              1.483470
# 92790             -0.371872             -0.521434             -0.674095
#
#        Number of Services_6  Number of Services_7  Number of Services_8  \
# 0                 -0.884681             -0.872396             -0.934433
# 1                 -0.884681             -0.872396             -0.934433
# 2                 -0.884681             -0.872396             -0.934433
# 3                 -0.884681             -0.872396             -0.934433
# 4                 -0.884681             -0.872396             -0.934433
# ...                     ...                   ...                   ...
# 92786             -0.884681              1.146269             -0.934433
# 92787             -0.884681              1.146269             -0.934433
# 92788             -0.884681             -0.872396             -0.934433
# 92789             -0.884681             -0.872396              1.070167
# 92790              1.130352             -0.872396             -0.934433
#
#        Number of Services_9  Number of Services_10  Number of Services_11  \
# 0                 -0.954407              -0.886288               0.953562
# 1                 -0.954407               1.128301              -1.048700
# 2                 -0.954407               1.128301               0.953562
# 3                  1.047771              -0.886288              -1.048700
# 4                  1.047771              -0.886288               0.953562
# ...                     ...                    ...                    ...
# 92786              1.047771               1.128301              -1.048700
# 92787             -0.954407               1.128301              -1.048700
# 92788              1.047771              -0.886288              -1.048700
# 92789             -0.954407               1.128301              -1.048700
# 92790              1.047771              -0.886288               0.953562
#
#        Number of Medicare Beneficiaries_0  Number of Medicare Beneficiaries_1  \
# 0                               -0.019425                           -0.142077
# 1                               -0.019425                           -0.142077
# 2                               -0.019425                           -0.142077
# 3                               -0.019425                           -0.142077
# 4                               -0.019425                           -0.142077
# ...                                   ...                                 ...
# 92786                           -0.019425                           -0.142077
# 92787                           -0.019425                           -0.142077
# 92788                           -0.019425                           -0.142077
# 92789                           -0.019425                           -0.142077
# 92790                           -0.019425                           -0.142077
#
#        Number of Medicare Beneficiaries_2  Number of Medicare Beneficiaries_3  \
# 0                               -0.245657                           -0.424926
# 1                               -0.245657                           -0.424926
# 2                               -0.245657                           -0.424926
# 3                               -0.245657                           -0.424926
# 4                               -0.245657                           -0.424926
# ...                                   ...                                 ...
# 92786                           -0.245657                           -0.424926
# 92787                           -0.245657                            2.353351
# 92788                           -0.245657                           -0.424926
# 92789                           -0.245657                            2.353351
# 92790                           -0.245657                           -0.424926
#
#        Number of Medicare Beneficiaries_4  Number of Medicare Beneficiaries_5  \
# 0                               -0.535685                           -0.785039
# 1                               -0.535685                           -0.785039
# 2                               -0.535685                           -0.785039
# 3                               -0.535685                           -0.785039
# 4                               -0.535685                           -0.785039
# ...                                   ...                                 ...
# 92786                            1.866768                            1.273822
# 92787                            1.866768                           -0.785039
# 92788                           -0.535685                           -0.785039
# 92789                           -0.535685                           -0.785039
# 92790                           -0.535685                            1.273822
#
#        Number of Medicare Beneficiaries_6  Number of Medicare Beneficiaries_7  \
# 0                               -0.876675                           -0.845774
# 1                               -0.876675                           -0.845774
# 2                               -0.876675                           -0.845774
# 3                               -0.876675                           -0.845774
# 4                               -0.876675                           -0.845774
# ...                                   ...                                 ...
# 92786                            1.140673                           -0.845774
# 92787                           -0.876675                           -0.845774
# 92788                           -0.876675                            1.182349
# 92789                           -0.876675                           -0.845774
# 92790                           -0.876675                           -0.845774
#
#        Number of Medicare Beneficiaries_8  Number of Medicare Beneficiaries_9  \
# 0                               -0.908461                           -1.104073
# 1                               -0.908461                            0.905737
# 2                               -0.908461                            0.905737
# 3                                1.100763                           -1.104073
# 4                               -0.908461                           -1.104073
# ...                                   ...                                 ...
# 92786                           -0.908461                            0.905737
# 92787                           -0.908461                           -1.104073
# 92788                           -0.908461                            0.905737
# 92789                            1.100763                           -1.104073
# 92790                           -0.908461                            0.905737
#
#        Number of Medicare Beneficiaries_10  \
# 0                                 0.912281
# 1                                -1.096153
# 2                                 0.912281
# 3                                -1.096153
# 4                                 0.912281
# ...                                    ...
# 92786                            -1.096153
# 92787                             0.912281
# 92788                            -1.096153
# 92789                            -1.096153
# 92790                            -1.096153
#
#        Number of Distinct Medicare Beneficiary/Per Day Services_0  \
# 0                                              -0.133634
# 1                                              -0.133634
# 2                                              -0.133634
# 3                                              -0.133634
# 4                                              -0.133634
# ...                                                  ...
# 92786                                          -0.133634
# 92787                                          -0.133634
# 92788                                          -0.133634
# 92789                                          -0.133634
# 92790                                          -0.133634
#
#        Number of Distinct Medicare Beneficiary/Per Day Services_1  \
# 0                                              -0.237005
# 1                                              -0.237005
# 2                                              -0.237005
# 3                                              -0.237005
# 4                                              -0.237005
# ...                                                  ...
# 92786                                          -0.237005
# 92787                                          -0.237005
# 92788                                          -0.237005
# 92789                                          -0.237005
# 92790                                          -0.237005
#
#        Number of Distinct Medicare Beneficiary/Per Day Services_2  \
# 0                                              -0.342968
# 1                                              -0.342968
# 2                                              -0.342968
# 3                                              -0.342968
# 4                                              -0.342968
# ...                                                  ...
# 92786                                          -0.342968
# 92787                                          -0.342968
# 92788                                          -0.342968
# 92789                                          -0.342968
# 92790                                          -0.342968
#
#        Number of Distinct Medicare Beneficiary/Per Day Services_3  \
# 0                                              -0.507932
# 1                                              -0.507932
# 2                                              -0.507932
# 3                                              -0.507932
# 4                                              -0.507932
# ...                                                  ...
# 92786                                          -0.507932
# 92787                                           1.968766
# 92788                                          -0.507932
# 92789                                           1.968766
# 92790                                          -0.507932
#
#        Number of Distinct Medicare Beneficiary/Per Day Services_4  \
# 0                                              -0.644334
# 1                                              -0.644334
# 2                                              -0.644334
# 3                                              -0.644334
# 4                                              -0.644334
# ...                                                  ...
# 92786                                           1.551991
# 92787                                          -0.644334
# 92788                                          -0.644334
# 92789                                          -0.644334
# 92790                                          -0.644334
#
#        Number of Distinct Medicare Beneficiary/Per Day Services_5  \
# 0                                              -0.859837
# 1                                              -0.859837
# 2                                              -0.859837
# 3                                              -0.859837
# 4                                              -0.859837
# ...                                                  ...
# 92786                                          -0.859837
# 92787                                          -0.859837
# 92788                                          -0.859837
# 92789                                           1.163011
# 92790                                           1.163011
#
#        Number of Distinct Medicare Beneficiary/Per Day Services_6  \
# 0                                              -0.955149
# 1                                              -0.955149
# 2                                              -0.955149
# 3                                              -0.955149
# 4                                              -0.955149
# ...                                                  ...
# 92786                                           1.046957
# 92787                                          -0.955149
# 92788                                          -0.955149
# 92789                                          -0.955149
# 92790                                          -0.955149
#
#        Number of Distinct Medicare Beneficiary/Per Day Services_7  \
# 0                                              -0.958310
# 1                                              -0.958310
# 2                                              -0.958310
# 3                                              -0.958310
# 4                                              -0.958310
# ...                                                  ...
# 92786                                          -0.958310
# 92787                                           1.043503
# 92788                                          -0.958310
# 92789                                           1.043503
# 92790                                          -0.958310
#
#        Number of Distinct Medicare Beneficiary/Per Day Services_8  \
# 0                                              -1.183240
# 1                                              -1.183240
# 2                                              -1.183240
# 3                                               0.845137
# 4                                               0.845137
# ...                                                  ...
# 92786                                          -1.183240
# 92787                                          -1.183240
# 92788                                           0.845137
# 92789                                          -1.183240
# 92790                                           0.845137
#
#        Number of Distinct Medicare Beneficiary/Per Day Services_9  \
# 0                                              -0.923321
# 1                                               1.083046
# 2                                               1.083046
# 3                                              -0.923321
# 4                                              -0.923321
# ...                                                  ...
# 92786                                          -0.923321
# 92787                                           1.083046
# 92788                                          -0.923321
# 92789                                          -0.923321
# 92790                                          -0.923321
#
#        Number of Distinct Medicare Beneficiary/Per Day Services_10  Anomaly  \
# 0                                               0.822055                  0
# 1                                              -1.216463                  0
# 2                                               0.822055                  0
# 3                                              -1.216463                  0
# 4                                               0.822055                  0
# ...                                                  ...                ...
# 92786                                          -1.216463                  0
# 92787                                          -1.216463                  0
# 92788                                          -1.216463                  0
# 92789                                           0.822055                  0
# 92790                                           0.822055                  0
#
#        Anomaly_Score
# 0          -0.091471
# 1          -0.081120
# 2          -0.097897
# 3          -0.108808
# 4          -0.095026
# ...              ...
# 92786      -0.049243
# 92787      -0.023419
# 92788      -0.051957
# 92789      -0.028771
# 92790      -0.079797
#
# [92791 rows x 101 columns]

# %%
i_ano['Anomaly'].value_counts()
# Out:
# 0    88151
# 1     4640
# Name: Anomaly, dtype: int64

# %%
#plot_model(iforest, plot = 'tsne')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\medical-fraud\main\anamoly-detection\main_pycaret.ipynb Cell 27 in 1
# ----> <a href='vscode-notebook-cell:/d%3A/medical-fraud/main/anamoly-detection/main_pycaret.ipynb#X44sZmlsZQ%3D%3D?line=0'>1</a> plot_model(iforest, plot = 'tsne')
#
# File c:\Users\mayank.monu\AppData\Local\Programs\Python\Python38\lib\site-packages\pycaret\utils\generic.py:965, in check_if_global_is_not_none.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     963     if globals_d[name] is None:
#     964         raise ValueError(message)
# --> 965 return func(*args, **kwargs)
#
# File c:\Users\mayank.monu\AppData\Local\Programs\Python\Python38\lib\site-packages\pycaret\anomaly\functional.py:699, in plot_model(model, plot, feature, label, scale, save, display_format)
#     636 @check_if_global_is_not_none(globals(), _CURRENT_EXPERIMENT_DECORATOR_DICT)
#     637 def plot_model(
#     638     model,
#    (...)
#     644     display_format: Optional[str] = None,
#     645 ) -> Optional[str]:
#     647     """
#     648     This function analyzes the performance of a trained model.
#     649
#    (...)
#     697
#     698     """
# --> 699     return _CURRENT_EXPERIMENT.plot_model(
#     700         model,
#     701         plot=plot,
#     702         feature_name=feature,
#     703         label=label,
#     704         scale=scale,
#     705         save=save,
#     706         display_format=display_format,
#     707     )
#
# File c:\Users\mayank.monu\AppData\Local\Programs\Python\Python38\lib\site-packages\pycaret\anomaly\oop.py:157, in AnomalyExperiment.plot_model(self, estimator, plot, scale, save, fold, fit_kwargs, plot_kwargs, groups, feature_name, label, use_train_data, verbose, display_format)
#      89 def plot_model(
#      90     self,
#      91     estimator,
#    (...)
#     103     display_format: Optional[str] = None,
#     104 ) -> Optional[str]:
#     105     """
#     106     This function analyzes the performance of a trained model.
#     107
#    (...)
#     155
#     156     """
# --> 157     return super().plot_model(
#     158         estimator,
#     159         plot,
#     160         scale,
#     161         save,
#     162         fold,
#     163         fit_kwargs,
#     164         plot_kwargs,
#     165         groups,
#     166         feature_name,
#     167         label,
#     168         use_train_data,
#     169         verbose,
#     170         display_format,
#     171     )
#
# File c:\Users\mayank.monu\AppData\Local\Programs\Python\Python38\lib\site-packages\pycaret\internal\pycaret_experiment\tabular_experiment.py:2078, in _TabularExperiment.plot_model(self, estimator, plot, scale, save, fold, fit_kwargs, plot_kwargs, groups, feature_name, label, use_train_data, verbose, display_format)
#    1964 def plot_model(
#    1965     self,
#    1966     estimator,
#    (...)
#    1978     display_format: Optional[str] = None,
#    1979 ) -> Optional[str]:
#    1981     """
#    1982     This function takes a trained model object and returns a plot based on the
#    1983     test / hold-out set. The process may require the model to be re-trained in
#    (...)
#    2076
#    2077     """
# -> 2078     return self._plot_model(
#    2079         estimator=estimator,
#    2080         plot=plot,
#    2081         scale=scale,
#    2082         save=save,
#    2083         fold=fold,
#    2084         fit_kwargs=fit_kwargs,
#    2085         plot_kwargs=plot_kwargs,
#    2086         groups=groups,
#    2087         feature_name=feature_name,
#    2088         label=label,
#    2089         use_train_data=use_train_data,
#    2090         verbose=verbose,
#    2091         display_format=display_format,
#    2092     )
#
# File c:\Users\mayank.monu\AppData\Local\Programs\Python\Python38\lib\site-packages\pycaret\internal\pycaret_experiment\tabular_experiment.py:1944, in _TabularExperiment._plot_model(self, estimator, plot, scale, save, fold, fit_kwargs, plot_kwargs, groups, feature_name, label, use_train_data, verbose, system, display, display_format)
#    1942 # execute the plot method
#    1943 with redirect_output(self.logger):
# -> 1944     ret = locals()[plot]()
#    1945 if ret:
#    1946     plot_filename = ret
#
# File c:\Users\mayank.monu\AppData\Local\Programs\Python\Python38\lib\site-packages\pycaret\internal\pycaret_experiment\tabular_experiment.py:793, in _TabularExperiment._plot_model.<locals>.tsne()
#     791     return _tsne_clustering()
#     792 else:
# --> 793     return _tsne_anomaly()
#
# File c:\Users\mayank.monu\AppData\Local\Programs\Python\Python38\lib\site-packages\pycaret\internal\pycaret_experiment\tabular_experiment.py:814, in _TabularExperiment._plot_model.<locals>._tsne_anomaly()
#     811 from sklearn.manifold import TSNE
#     813 self.logger.info("Fitting TSNE()")
# --> 814 X_embedded = TSNE(n_components=3).fit_transform(b)
#     816 X = pd.DataFrame(X_embedded)
#     817 X["Anomaly"] = cluster
#
# File c:\Users\mayank.monu\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\manifold\_t_sne.py:1123, in TSNE.fit_transform(self, X, y)
#    1103 """Fit X into an embedded space and return that transformed output.
#    1104
#    1105 Parameters
#    (...)
#    1120     Embedding of the training data in low-dimensional space.
#    1121 """
#    1122 self._check_params_vs_input(X)
# -> 1123 embedding = self._fit(X)
#    1124 self.embedding_ = embedding
#    1125 return self.embedding_
#
# File c:\Users\mayank.monu\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\manifold\_t_sne.py:1018, in TSNE._fit(self, X, skip_num_points)
#    1012 # Degrees of freedom of the Student's t-distribution. The suggestion
#    1013 # degrees_of_freedom = n_components - 1 comes from
#    1014 # "Learning a Parametric Embedding by Preserving Local Structure"
#    1015 # Laurens van der Maaten, 2009.
#    1016 degrees_of_freedom = max(self.n_components - 1, 1)
# -> 1018 return self._tsne(
#    1019     P,
#    1020     degrees_of_freedom,
#    1021     n_samples,
#    1022     X_embedded=X_embedded,
#    1023     neighbors=neighbors_nn,
#    1024     skip_num_points=skip_num_points,
#    1025 )
#
# File c:\Users\mayank.monu\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\manifold\_t_sne.py:1070, in TSNE._tsne(self, P, degrees_of_freedom, n_samples, X_embedded, neighbors, skip_num_points)
#    1067 # Learning schedule (part 1): do 250 iteration with lower momentum but
#    1068 # higher learning rate controlled via the early exaggeration parameter
#    1069 P *= self.early_exaggeration
# -> 1070 params, kl_divergence, it = _gradient_descent(obj_func, params, **opt_args)
#    1071 if self.verbose:
#    1072     print(
#    1073         "[t-SNE] KL divergence after %d iterations with early exaggeration: %f"
#    1074         % (it + 1, kl_divergence)
#    1075     )
#
# File c:\Users\mayank.monu\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\manifold\_t_sne.py:398, in _gradient_descent(objective, p0, it, n_iter, n_iter_check, n_iter_without_progress, momentum, learning_rate, min_gain, min_grad_norm, verbose, args, kwargs)
#     395 # only compute the error when needed
#     396 kwargs["compute_error"] = check_convergence or i == n_iter - 1
# --> 398 error, grad = objective(p, *args, **kwargs)
#     399 grad_norm = linalg.norm(grad)
#     401 inc = update * grad < 0.0
#
# File c:\Users\mayank.monu\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\manifold\_t_sne.py:279, in _kl_divergence_bh(params, P, degrees_of_freedom, n_samples, n_components, angle, skip_num_points, verbose, compute_error, num_threads)
#     276 indptr = P.indptr.astype(np.int64, copy=False)
#     278 grad = np.zeros(X_embedded.shape, dtype=np.float32)
# --> 279 error = _barnes_hut_tsne.gradient(
#     280     val_P,
#     281     X_embedded,
#     282     neighbors,
#     283     indptr,
#     284     grad,
#     285     angle,
#     286     n_components,
#     287     verbose,
#     288     dof=degrees_of_freedom,
#     289     compute_error=compute_error,
#     290     num_threads=num_threads,
#     291 )
#     292 c = 2.0 * (degrees_of_freedom + 1.0) / degrees_of_freedom
#     293 grad = grad.ravel()
#
# KeyboardInterrupt:
